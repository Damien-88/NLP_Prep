# %% [markdown]
# # Week X: [Task Name]
#
# ## Date
# [Fill in]
#
# ## Time Spent
# [Fill in]
#
# ---
#
# ## Objective
# What are you trying to implement or learn?
#
# ---
#
# ## Dataset
# - Source:
# - Size:
# - Preprocessing steps:
#
# ---
#
# ## Method
# Describe model/algorithm (n-gram, HMM, etc.)
#
# ---
#
# ## Implementation
# (Code below)
#
# ---
#
# ## Results
# - Metrics (accuracy, perplexity, etc.)
# - Tables / plots
#
# ---
#
# ## Observations
# - What worked?
# - What didn’t?
# - Language-specific issues?
#
# ---
#
# ## Next Steps
# What will you try next?
#
# ---
#
# ## References
# - Book chapters
# - Papers
# - URLs
